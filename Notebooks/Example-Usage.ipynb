# %%
cd ../
# Out:
# d:\OneDrive\Documents\Monash Research Project T2 2022\HazardousWaste

# %%
from Lib.TextAnalytics.KeywordExtraction import *
from Lib.TextAnalytics.Clustering import *
from SearchScholar import *

# %%
result_path = search_scholar(['Hazardous', 'Waste'], 10)
# Out:
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=50
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=60
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=80
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=40
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=30
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=0
# Running Google Search at https://scholar.google.com.au/scholar?as_q=Hazardous%20Waste&as_publication=&as_ylo=2015&as_yhi=2022&start=70
# ...

# %%
(keywords, vocabulary) = extract_keywords_from_results(result_path)

# %%
clustering_results = cluster_documents(keywords, vocabulary)
