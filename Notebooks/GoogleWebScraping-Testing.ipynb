# %%
cd ../
# Out:
# d:\OneDrive\Documents\Monash Research Project T2 2022\HazardousWaste

# %%
from Lib.WebScrapping.CorpusScraper import *

# %%
webpages = get_tag_corpus(["metal", "battery", "Solid waste"], 1)
# Out:
# 2022-09-07 06:44:38 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-09-07 06:44:38 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.10.4 | packaged by conda-forge | (main, Mar 30 2022, 08:38:02) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1q  5 Jul 2022), cryptography 37.0.1, Platform Windows-10-10.0.19044-SP0
# 2022-09-07 06:44:38 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Edg/105.0.1343.27'}
# 2022-09-07 06:44:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-09-07 06:44:38 [scrapy.extensions.telnet] INFO: Telnet Password: ab57fc4e10c63f5c
# 2022-09-07 06:44:38 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %%
for webpage in webpages:
    print(webpage.title)
    print(webpage.url)
